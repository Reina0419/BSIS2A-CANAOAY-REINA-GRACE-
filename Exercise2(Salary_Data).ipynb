# %% [markdown]
# <a href="https://colab.research.google.com/github/Reina0419/BSIS2A-CANAOAY-REINA-GRACE-/blob/main/Exercise2(Salary_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Reina0419/BSIS2A-CANAOAY-REINA-GRACE-/main/SALARY_DATA.csv')

# %%
sns.histplot(df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
plt.show()

# %%
df1=sns.catplot(data=df,col = "Name",x ="Salary",kind="count")

# %%
df_h=df.groupby(['Name','Salary']).size().head(10)

# %%
(df_h.head())
# Out:
# Name     Salary
# Alice    54000     1
# Bob      78000     1
# Charlie  66000     1
# David    72000     1
# Eva      85000     1
# dtype: int64

# %%
top_5=df_h.sort_values(ascending = True).head(5)

# %%
top_5.plot(kind='bar')
plt.title('Total Salary')
plt.xlabel('Name')
plt.ylabel('Highest Salary')
plt.show()

# %%
df_h=df.groupby(['Department']).size().head(10)

# %%
print(df_h)
# Out:
# Department
# Finance      3
# HR           3
# IT           3
# Marketing    3
# Sales        3
# dtype: int64

# %%
df_h.plot(kind='pie')
plt.title('Department')
plt.show()

# %%
df_h.plot(kind='line')
plt.title('Department')
plt.show()

# %%
df_h=df.groupby(['Salary']).size().head(10)

# %%
df_h.plot(kind='pie')
plt.title('Total Salary')
plt.show()

# %%
df_h.plot(kind='line')
plt.title('Total Salary')
plt.show()

# %%
age_info = df[df['Age'].notnull()][['Age']]

#Dropping values of age = 0
age_info_clean = age_info[age_info['Age'] != 0]

age_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     15 non-null     int64
# dtypes: int64(1)
# memory usage: 248.0 bytes

# %%
fig = plt.figure(figsize = (20,8))
Age_plot = sns.distplot(age_info_clean, bins = 30)
Age_plot.tick_params(labelsize = 13)

std= age_info['Age'].std()
plt.xlabel('Age', fontdict = {'fontsize':15})
plt.title('Age of disease-affected humans', fontdict = {'fontsize':15})
plt.bold=True
plt.axvline(std,color = 'red')
plt.show()
# Out:
# <ipython-input-73-4e3244fe1de0>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   Age_plot = sns.distplot(age_info_clean, bins = 30)
